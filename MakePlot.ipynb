# %%
default_results = [
    15.848381025,
    22.829635284,
    128.503351302,
    19.257809818,
    125.939522797,
    20.823880103,
    25.330428753,
    19.708372261,
    26.397634941,
    16.590082002,
]

# %%
customized_results = [
    13.281077128,
    13.48135304,
    13.099032896,
    13.208222995,
    13.466480764,
    13.5598017,
    13.325801038,
    13.285316471,
    12.948737134,
    13.371411042,
]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(8,6)})

# %%
plt.plot(range(10), default_results, color='red')
plt.plot(range(10), customized_results, color='blue', )
plt.grid(True)
plt.figlegend(['http.DefaultTransport', 'oneHostTransport']);

# %%
import numpy as np

default_mean, default_std = np.mean(default_results), np.std(default_results)
customized_mean, customized_std = np.mean(customized_results), np.std(customized_results)

print(f'Default result: {default_mean} ± {default_std}')
print(f'Customized result: {customized_mean} ± {customized_std}')
# Out:
# Default result: 42.12290982859999 ± 42.6725398037689
# Customized result: 13.302723420800001 ± 0.17508935752097912
